# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("D:/all project/python ML project/diabetes  prediction/diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# data using head and tail

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.info()# quick datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe() # understanding by describe
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.describe(include=[int])
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               Age     Outcome
# count  768.000000  768.000000
# mean    33.240885    0.348958
# std     11.760232    0.476951
# min     21.000000    0.000000
# 25%     24.000000    0.000000
# 50%     29.000000    0.000000
# 75%     41.000000    1.000000
# max     81.000000    1.000000

# %%
df.describe(exclude=[int])
# Out:
#               BMI  DiabetesPedigreeFunction
# count  768.000000                768.000000
# mean    31.992578                  0.471876
# std      7.884160                  0.331329
# min      0.000000                  0.078000
# 25%     27.300000                  0.243750
# 50%     32.000000                  0.372500
# 75%     36.600000                  0.626250
# max     67.100000                  2.420000

# %%
df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
# sape of data
df.shape
# Out:
# (768, 9)

# %%
# get no of rows
df.shape[0]
# Out:
# 768

# %%
# no of column 
df.shape[1]
# Out:
# 9

# %%
# get all columns & columns name
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
# check the missing values
df.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# lest create missing value
df2=df.copy()
df2.loc[2:5, 'Pregnancies']= None
df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0      148             72             35        0  33.6
# 1            1.0       85             66             29        0  26.6
# 2            NaN      183             64              0        0  23.3
# 3            NaN       89             66             23       94  28.1
# 4            NaN      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0      101             76             48      180  32.9
# 764          2.0      122             70             27        0  36.8
# 765          5.0      121             72             23      112  26.2
# 766          1.0      126             60              0        0  30.1
# 767          1.0       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df2.head(7)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0      148             72             35        0  33.6
# 1          1.0       85             66             29        0  26.6
# 2          NaN      183             64              0        0  23.3
# 3          NaN       89             66             23       94  28.1
# 4          NaN      137             40             35      168  43.1
# 5          NaN      116             74              0        0  25.6
# 6          3.0       78             50             32       88  31.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1

# %%
df2.isnull().sum()
# Out:
# Pregnancies                 4
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df2.isnull().sum().sum()
# Out:
# 4

# %%
# sclicing and extracting data in pandas
df['Glucose']
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64

# %%
df[['Pregnancies','Glucose','Insulin']]
# Out:
#      Pregnancies  Glucose  Insulin
# 0              6      148        0
# 1              1       85        0
# 2              8      183        0
# 3              1       89       94
# 4              0      137      168
# ..           ...      ...      ...
# 763           10      101      180
# 764            2      122        0
# 765            5      121      112
# 766            1      126        0
# 767            1       93        0
#
# [768 rows x 3 columns]

# %%
# isloating one row
df[df.index==1]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 1                     0.351   31        0

# %%
# isloating one row
df[df.index==0]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1

# %%
# isolating two or more row
df[df.index.isin (range(2,11))]
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
#
#     DiabetesPedigreeFunction  Age  Outcome
# 2                      0.672   32        1
# 3                      0.167   21        0
# 4                      2.288   33        1
# 5                      0.201   30        0
# 6                      0.248   26        1
# ...

# %%
# using .loc and iloc to fetch row
df.loc[1]
# Out:
# Pregnancies                  1.000
# Glucose                     85.000
# BloodPressure               66.000
# SkinThickness               29.000
# Insulin                      0.000
# BMI                         26.600
# DiabetesPedigreeFunction     0.351
# Age                         31.000
# Outcome                      0.000
# Name: 1, dtype: float64

# %%
df.iloc[1]
# Out:
# Pregnancies                  1.000
# Glucose                     85.000
# BloodPressure               66.000
# SkinThickness               29.000
# Insulin                      0.000
# BMI                         26.600
# DiabetesPedigreeFunction     0.351
# Age                         31.000
# Outcome                      0.000
# Name: 1, dtype: float64

# %%
df2.loc[100:250]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 100          1.0      163             72              0        0  39.0
# 101          1.0      151             60              0        0  26.1
# 102          0.0      125             96              0        0  22.5
# 103          1.0       81             72             18       40  26.6
# 104          2.0       85             65              0        0  39.6
# ..           ...      ...            ...            ...      ...   ...
# 246         10.0      122             68              0        0  31.2
# 247          0.0      165             90             33      680  52.3
# 248          9.0      124             70             33      402  35.4
# 249          1.0      111             86             19        0  30.1
# 250          9.0      106             52              0        0  31.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 100                     1.222   33        1
# ...

# %%
df2.iloc[150:700]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 150          1.0      136             74             50      204  37.4
# 151          4.0      114             65              0        0  21.9
# 152          9.0      156             86             28      155  34.3
# 153          1.0      153             82             42      485  40.6
# 154          8.0      188             78              0        0  47.9
# ..           ...      ...            ...            ...      ...   ...
# 695          7.0      142             90             24      480  30.4
# 696          3.0      169             74             19      125  29.9
# 697          0.0       99              0              0        0  25.0
# 698          4.0      127             88             11      155  34.5
# 699          4.0      118             70              0        0  44.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 150                     0.399   24        0
# ...

# %%
df2.iloc[100:600:300]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 100          1.0      163             72              0        0  39.0
# 400          4.0       95             64              0        0  32.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 100                     1.222   33        1
# 400                     0.161   31        1

# %%
df2.loc[100:600:200]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 100          1.0      163             72              0        0  39.0
# 300          0.0      167              0              0        0  32.3
# 500          2.0      117             90             19       71  25.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 100                     1.222   33        1
# 300                     0.839   30        1
# 500                     0.313   21        0

# %%
df2.loc[100:600,['Pregnancies','Glucose','SkinThickness']]
# Out:
#      Pregnancies  Glucose  SkinThickness
# 100          1.0      163              0
# 101          1.0      151              0
# 102          0.0      125              0
# 103          1.0       81             18
# 104          2.0       85              0
# ..           ...      ...            ...
# 596          0.0       67              0
# 597          1.0       89             19
# 598          1.0      173              0
# 599          1.0      109             18
# 600          1.0      108             19
#
# [501 rows x 3 columns]

# %%
df2.iloc[100:200,:5]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin
# 100          1.0      163             72              0        0
# 101          1.0      151             60              0        0
# 102          0.0      125             96              0        0
# 103          1.0       81             72             18       40
# 104          2.0       85             65              0        0
# ..           ...      ...            ...            ...      ...
# 195          5.0      158             84             41      210
# 196          1.0      105             58              0        0
# 197          3.0      107             62             13       48
# 198          4.0      109             64             44       99
# 199          4.0      148             60             27      318
#
# [100 rows x 5 columns]

# %%
df2.loc[:750,['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness']]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness
# 0            6.0      148             72             35
# 1            1.0       85             66             29
# 2            NaN      183             64              0
# 3            NaN       89             66             23
# 4            NaN      137             40             35
# ..           ...      ...            ...            ...
# 746          1.0      147             94             41
# 747          1.0       81             74             41
# 748          3.0      187             70             22
# 749          6.0      162             62              0
# 750          4.0      136             70              0
#
# [751 rows x 4 columns]

# %%
df2.iloc[750:, :3]
# Out:
#      Pregnancies  Glucose  BloodPressure
# 750          4.0      136             70
# 751          1.0      121             78
# 752          3.0      108             62
# 753          0.0      181             88
# 754          8.0      154             78
# 755          1.0      128             88
# 756          7.0      137             90
# 757          0.0      123             72
# 758          1.0      106             76
# 759          6.0      190             92
# 760          2.0       88             58
# 761          9.0      170             74
# 762          9.0       89             62
# 763         10.0      101             76
# 764          2.0      122             70
# 765          5.0      121             72
# 766          1.0      126             60
# 767          1.0       93             70

# %%
# conditional sclicing
df[df.BloodPressure==85]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 69             4      146             85             27      100  28.9
# 109            0       95             85             25       36  37.4
# 211            0      147             85             54        0  42.8
# 245            9      184             85             15        0  30.0
# 436           12      140             85             33        0  37.4
# 542           10       90             85             32        0  34.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 69                      0.189   27        0
# 109                     0.247   24        1
# 211                     0.375   24        0
# 245                     1.213   49        1
# 436                     0.244   41        0
# 542                     0.825   56        1

# %%
df[df.Glucose==96]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 106            1       96            122              0        0  22.4
# 134            2       96             68             13       49  21.1
# 208            1       96             64             27       87  33.2
# 265            5       96             74             18       67  33.6
# 288            4       96             56             17       49  20.8
# 396            3       96             56             34      115  24.7
# 504            3       96             78             39        0  37.3
# 601            6       96              0              0        0  23.7
#
#      DiabetesPedigreeFunction  Age  Outcome
# 106                     0.207   27        0
# 134                     0.647   26        0
# 208                     0.289   21        0
# 265                     0.997   43        0
# 288                     0.340   26        0
# 396                     0.944   39        0
# ...

# %%
df[df.Outcome==1]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.loc[df.BloodPressure>100,['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness']]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness
# 43             9      171            110             24
# 84             5      137            108              0
# 106            1       96            122              0
# 177            0      129            110             46
# 207            5      162            104              0
# 362            5      103            108             37
# 369            1      133            102             28
# 440            0      189            104             25
# 549            4      189            110             31
# 658           11      127            106              0
# 662            8      167            106             46
# 672           10       68            106             23
# 691           13      158            114              0

# %%
# cleaning data 
df2.isnull().sum()
# Out:
# Pregnancies                 4
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# dealing with missing data

# %%
df3=df2.copy()

# %%
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0      148             72             35        0  33.6
# 1            1.0       85             66             29        0  26.6
# 2            NaN      183             64              0        0  23.3
# 3            NaN       89             66             23       94  28.1
# 4            NaN      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0      101             76             48      180  32.9
# 764          2.0      122             70             27        0  36.8
# 765          5.0      121             72             23      112  26.2
# 766          1.0      126             60              0        0  30.1
# 767          1.0       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df3=df3.dropna()

# %%
df3.shape
# Out:
# (764, 9)

# %%
df2.shape
# Out:
# (768, 9)

# %%
df2.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0      148             72             35        0  33.6
# 1          1.0       85             66             29        0  26.6
# 2          NaN      183             64              0        0  23.3
# 3          NaN       89             66             23       94  28.1
# 4          NaN      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df3=df2.copy()

# %%
df3.dropna(inplace =True, axis=1)

# %%
df3.head()
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df3=df2.copy()

# %%
df3.dropna(inplace=True,how='all')
df3.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0      148             72             35        0  33.6
# 1          1.0       85             66             29        0  26.6
# 2          NaN      183             64              0        0  23.3
# 3          NaN       89             66             23       94  28.1
# 4          NaN      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df3.dropna(inplace=True,axis=1)

# %%
df3.head()
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# replacing missing value

# %%
df3=df2.copy()

# %%
mean_value=df3['Pregnancies'].mean()

# %%
df3=df3.fillna(mean_value)

# %%
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0       6.000000      148             72             35        0  33.6
# 1       1.000000       85             66             29        0  26.6
# 2       3.846859      183             64              0        0  23.3
# 3       3.846859       89             66             23       94  28.1
# 4       3.846859      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763    10.000000      101             76             48      180  32.9
# 764     2.000000      122             70             27        0  36.8
# 765     5.000000      121             72             23      112  26.2
# 766     1.000000      126             60              0        0  30.1
# 767     1.000000       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# dealing with duplicate data

# %%
df3=pd.concat([df2,df2])

# %%
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0      148             72             35        0  33.6
# 1            1.0       85             66             29        0  26.6
# 2            NaN      183             64              0        0  23.3
# 3            NaN       89             66             23       94  28.1
# 4            NaN      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0      101             76             48      180  32.9
# 764          2.0      122             70             27        0  36.8
# 765          5.0      121             72             23      112  26.2
# 766          1.0      126             60              0        0  30.1
# 767          1.0       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df3.shape
# Out:
# (1536, 9)

# %%
df3=df3.drop_duplicates()

# %%
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0      148             72             35        0  33.6
# 1            1.0       85             66             29        0  26.6
# 2            NaN      183             64              0        0  23.3
# 3            NaN       89             66             23       94  28.1
# 4            NaN      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0      101             76             48      180  32.9
# 764          2.0      122             70             27        0  36.8
# 765          5.0      121             72             23      112  26.2
# 766          1.0      126             60              0        0  30.1
# 767          1.0       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df3.shape
# Out:
# (768, 9)

# %%
df3.rename(columns={'DiabetesPedigreeFunction':'DPF'}, inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_57004\2463880070.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.rename(columns={'DiabetesPedigreeFunction':'DPF'}, inplace=True)

# %%
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI    DPF  \
# 0            6.0      148             72             35        0  33.6  0.627
# 1            1.0       85             66             29        0  26.6  0.351
# 2            NaN      183             64              0        0  23.3  0.672
# 3            NaN       89             66             23       94  28.1  0.167
# 4            NaN      137             40             35      168  43.1  2.288
# ..           ...      ...            ...            ...      ...   ...    ...
# 763         10.0      101             76             48      180  32.9  0.171
# 764          2.0      122             70             27        0  36.8  0.340
# 765          5.0      121             72             23      112  26.2  0.245
# 766          1.0      126             60              0        0  30.1  0.349
# 767          1.0       93             70             31        0  30.4  0.315
#
#      Age  Outcome
# ...

# %%
df3.columns=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# %%
df3.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0      148             72             35        0  33.6
# 1          1.0       85             66             29        0  26.6
# 2          NaN      183             64              0        0  23.3
# 3          NaN       89             66             23       94  28.1
# 4          NaN      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# data analysis in pandas

# %%
# summery operation (mean ,mode, median)

# %%
df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
df.mode()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          1.0       99           70.0            0.0      0.0  32.0
# 1          NaN      100            NaN            NaN      NaN   NaN
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.254  22.0      0.0
# 1                     0.258   NaN      NaN

# %%
df.median()
# Out:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                23.0000
# Insulin                      30.5000
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# dtype: float64

# %%
# create new column base on exsisting columns

# %%
df2['glucose_insulin_ratio']=df2['Glucose']/df2['Insulin']

# %%
df2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0      148             72             35        0  33.6
# 1            1.0       85             66             29        0  26.6
# 2            NaN      183             64              0        0  23.3
# 3            NaN       89             66             23       94  28.1
# 4            NaN      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0      101             76             48      180  32.9
# 764          2.0      122             70             27        0  36.8
# 765          5.0      121             72             23      112  26.2
# 766          1.0      126             60              0        0  30.1
# 767          1.0       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  glucose_insulin_ratio
# ...

# %%
# counting values of columns
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
df['Outcome'].value_counts(normalize=True) # show in percentage of part
# Out:
# 0    0.651042
# 1    0.348958
# Name: Outcome, dtype: float64

# %%
df['Outcome'].value_counts(sort=True)# sort
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
df['Outcome'].value_counts(sort=False)
# Out:
# 1    268
# 0    500
# Name: Outcome, dtype: int64

# %%
df.value_counts(subset=['Pregnancies','Outcome'])
# Out:
# Pregnancies  Outcome
# 1            0          106
# 2            0           84
# 0            0           73
# 3            0           48
# 4            0           45
# 0            1           38
# 5            0           36
# 6            0           34
# 1            1           29
# 3            1           27
# 7            1           25
# 4            1           23
# 8            1           22
# 5            1           21
# 7            0           20
# 2            1           19
# 9            1           18
# 6            1           16
# 8            0           16
# 10           0           14
#              1           10
# 9            0           10
# 11           1            7
# 12           0            5
# 13           0            5
#              1            5
# 11           0            4
# 12           1            4
# 14           1            2
# 15           1            1
# 17           1            1
# dtype: int64

# %%
# aggregating data by group by in panda
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
df.groupby(['Pregnancies','Outcome']).mean()
# Out:
#                         Glucose  BloodPressure  SkinThickness     Insulin  \
# Pregnancies Outcome
# 0           0        111.945205      69.205479      21.054795   77.561644
#             1        144.236842      63.210526      24.605263   89.578947
# 1           0        104.254717      66.830189      23.047170   84.320755
#             1        143.793103      71.310345      29.517241  151.137931
# 2           0        105.214286      61.940476      20.107143   72.619048
#             1        135.473684      69.052632      28.210526  144.315789
# 3           0        109.604167      65.708333      17.520833   62.020833
#             1        148.444444      68.148148      24.629630  132.666667
# 4           0        117.555556      71.577778      18.422222   78.466667
#             1        139.913043      67.000000      10.913043   51.782609
# 5           0        111.666667      74.666667      17.166667   46.861111
# ...

# %%
#pivot table

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
pd.pivot_table(df,values='BMI',index='Pregnancies', columns=['Outcome'],aggfunc=np.mean)
# Out:
# Outcome              0          1
# Pregnancies
# 0            31.727397  39.213158
# 1            29.616038  37.793103
# 2            29.679762  34.578947
# 3            29.231250  32.548148
# 4            31.255556  33.873913
# 5            31.100000  36.780952
# 6            29.591176  31.775000
# 7            29.975000  34.756000
# 8            30.693750  32.204545
# 9            28.840000  33.300000
# 10           30.114286  31.380000
# 11           37.125000  39.385714
# 12           30.560000  34.575000
# 13           33.280000  36.720000
# 14                 NaN  35.100000
# 15                 NaN  37.100000
# 17                 NaN  40.900000

# %%
# data visullisation in pandas

# %%
df[['BMI','Glucose','Pregnancies']].plot.line()
# Out:
# <AxesSubplot: >

# %%
df[['BMI','Glucose']].plot.line(figsize=(15,10),color={'BMI':'red','Glucose':'blue'})
# Out:
# <AxesSubplot: >

# %%
df.plot.line(figsize=(15,10),subplots=True)
# Out:
# array([<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >,
#        <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >,
#        <AxesSubplot: >], dtype=object)

# %%
df['Outcome'].value_counts().plot.bar()
# Out:
# <AxesSubplot: >

# %%
df.boxplot(column='BMI',by='Outcome')
# Out:
# <AxesSubplot: title={'center': 'BMI'}, xlabel='Outcome'>
